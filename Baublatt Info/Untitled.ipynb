# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("test_bp.csv" , sep=';', na_filter=False, encoding='latin-1')
data
# Out:
#       ObjektNr     BHNr          BHAnr                      BHBriefAnr  \
# 0     99836388  2406750          Firma  Sehr geehrte Damen und Herren
# 1     99836392  2406750          Firma  Sehr geehrte Damen und Herren
# 2     99837290  2279669          Firma  Sehr geehrte Damen und Herren
# 3     99836511  2748880  Herr und Frau     Sehr geehrte Bauherrschaft
# 4     99844840  2754575          Firma  Sehr geehrte Damen und Herren
# ...        ...      ...            ...                             ...
# 7633  99831996  2680152          Firma  Sehr geehrte Damen und Herren
# 7634  99834130  2701182          Firma  Sehr geehrte Damen und Herren
# 7635  99829383  2744017                 Sehr geehrte Damen und Herren
# 7636  99834328  2726075          Firma  Sehr geehrte Damen und Herren
# 7637  99831599  2680152          Firma  Sehr geehrte Damen und Herren
#
#                              BHName BHVorname                      BHBranche  \
# ...

# %%
# Out:
#       ObjektNr     BHNr          BHAnr                      BHBriefAnr  \
# 0     99836388  2406750          Firma  Sehr geehrte Damen und Herren
# 1     99836392  2406750          Firma  Sehr geehrte Damen und Herren
# 2     99837290  2279669          Firma  Sehr geehrte Damen und Herren
# 3     99836511  2748880  Herr und Frau     Sehr geehrte Bauherrschaft
# 4     99844840  2754575          Firma  Sehr geehrte Damen und Herren
# ...        ...      ...            ...                             ...
# 7633  99831996  2680152          Firma  Sehr geehrte Damen und Herren
# 7634  99834130  2701182          Firma  Sehr geehrte Damen und Herren
# 7635  99829383  2744017                 Sehr geehrte Damen und Herren
# 7636  99834328  2726075          Firma  Sehr geehrte Damen und Herren
# 7637  99831599  2680152          Firma  Sehr geehrte Damen und Herren
#
#                              BHName BHVorname                      BHBranche  \
# ...

# %%
data2 = np.genfromtxt("2006_01_KOF_9943D2K.csv",delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-567874a36569> in <module>
# ----> 1 data2 = np.genfromtxt("2006_01_KOF_9943D2K.csv",delimiter=';')
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2087             # Raise an exception ?
#    2088             if invalid_raise:
# -> 2089                 raise ValueError(errmsg)
#    2090             # Issue a warning ?
#    2091             else:
#
# ValueError: Some errors were detected !
#     Line #4469 (got 158 columns instead of 175)
#     Line #4473 (got 26 columns instead of 175)
#     Line #7295 (got 26 columns instead of 175)
# ...

# %%
data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-eff1098d818d> in <module>
# ----> 1 data2
#
# NameError: name 'data2' is not defined
