# %%
# Import necessary packages
import os

import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
import rasterio as rio #for gespatial raster data 

# Earthpy is an earthlab package to work with spatial data
import earthpy as et
import earthpy.plot as ep

# Get data and set working directory

#Ich ziehe mir hier die Daten
et.data.get_data("colorado-flood")
#Ich generiere mir hier den Pfad
os.chdir(os.path.join(et.io.HOME, 'earth-analytics', 'data'))


#pip install earthpy
#conda install gepandas

# %%
#https://www.earthdatascience.org/courses/intro-to-earth-data-science/file-formats/use-spatial-data/use-raster-data/

# %%
# 1. Get the Data 
# 1.1 Create Path 
lidar_dtm_path = os.path.join("colorado-flood",
                              "spatial",
                              "boulder-leehill-rd",
                              "pre-flood",
                              "lidar",
                              "pre_DTM.tif")
print(lidar_dtm_path)

#1.2 Open the data as raster file
with rio.open(lidar_dtm_path) as src:
    lidar_dtm = src.read(1, masked=True)

# View the data - notice the data structure is different from geopandas data
# which you explored in the last lesson
type(lidar_dtm)
# Out:
# colorado-flood\spatial\boulder-leehill-rd\pre-flood\lidar\pre_DTM.tif
# numpy.ma.core.MaskedArray

# %%
lidar_dtm.shape
ep.plot_bands(lidar_dtm,
              scale=False,
              cmap='Greys',
              title="Lidar Digital Terrain Model")
plt.show()

# %%
lidar_dtm
# Out:
# masked_array(
#   data=[[--, --, --, ..., 1695.6300048828125, 1695.419921875,
#          1695.429931640625],
#         [--, --, --, ..., 1695.5999755859375, 1695.5399169921875,
#          1695.3599853515625],
#         [--, --, --, ..., 1695.3800048828125, 1695.43994140625,
#          1695.3699951171875],
#         ...,
#         [--, --, --, ..., 1681.449951171875, 1681.3900146484375, 1681.25],
#         [--, --, --, ..., 1681.719970703125, 1681.5699462890625,
#          1681.5599365234375],
#         [--, --, --, ..., 1681.8900146484375, 1681.8099365234375,
#          1681.739990234375]],
#   mask=[[ True,  True,  True, ..., False, False, False],
#         [ True,  True,  True, ..., False, False, False],
#         [ True,  True,  True, ..., False, False, False],
#         ...,
#         [ True,  True,  True, ..., False, False, False],
#         [ True,  True,  True, ..., False, False, False],
#         [ True,  True,  True, ..., False, False, False]],
# ...

# %%
#Data Tip: For larger raster data processing it is common to use xarray which is 
#incorporates some of rasterio’s functionality but also supports big data processing

# %%
# Chapter 5 - Sue Vector Data
# Lesson 3. Introduction to Spatial Vector Data File Formats in Open Source Python

# Geopandas is for vector data

"""Vector data are composed of discrete geometric locations (x, y values) known as vertices that 
define the “shape” of the spatial object. The organization of the vertices determines 
the type of vector that you are working with. There are three types of vector data:"""
# Out:
# 'Vector data are composed of discrete geometric locations (x, y values) known as vertices that \ndefine the “shape” of the spatial object. The organization of the vertices determines \nthe type of vector that you are working with. There are three types of vector data:'

# %%
# Download the data and set working directory
et.data.get_data(
    url='https://www.naturalearthdata.com/http//www.naturalearthdata.com/download/50m/cultural/ne_50m_admin_0_boundary_lines_land.zip')

# Set working directory - earthpy creates earth-analytics for you in your home dir
os.chdir(os.path.join(et.io.HOME, 'earth-analytics'))

# %%
coastlines_url = "https://www.naturalearthdata.com/http//www.naturalearthdata.com/download/50m/physical/ne_50m_coastline.zip"

et.data.get_data(url=coastlines_url)

coastlines_path = os.path.join("data", "earthpy-downloads",
                               "ne_50m_coastline",
                               "ne_50m_coastline.shp")

coastlines = gpd.read_file(coastlines_path)
coastlines.head()
# Out:
#    scalerank featurecla  min_zoom  \
# 0          0  Coastline       1.5
# 1          0  Coastline       4.0
# 2          0  Coastline       4.0
# 3          0  Coastline       3.0
# 4          0  Coastline       4.0
#
#                                             geometry
# 0  LINESTRING (180.00000 -16.15293, 179.84814 -16...
# 1  LINESTRING (177.25752 -17.05420, 177.28740 -17...
# 2  LINESTRING (127.37266 0.79131, 127.35381 0.847...
# 3  LINESTRING (-81.32231 24.68506, -81.42007 24.7...
# 4  LINESTRING (-80.79941 24.84629, -80.83887 24.8...

# %%
coastlines
# Out:
#       scalerank featurecla  min_zoom  \
# 0             0  Coastline       1.5
# 1             0  Coastline       4.0
# 2             0  Coastline       4.0
# 3             0  Coastline       3.0
# 4             0  Coastline       4.0
# ...         ...        ...       ...
# 1423          0  Coastline       4.0
# 1424          0  Coastline       4.0
# 1425          0  Coastline       4.0
# 1426          0  Coastline       4.0
# 1427          0  Coastline       4.0
#
#                                                geometry
# 0     LINESTRING (180.00000 -16.15293, 179.84814 -16...
# 1     LINESTRING (177.25752 -17.05420, 177.28740 -17...
# 2     LINESTRING (127.37266 0.79131, 127.35381 0.847...
# 3     LINESTRING (-81.32231 24.68506, -81.42007 24.7...
# 4     LINESTRING (-80.79941 24.84629, -80.83887 24.8...
# ...                                                 ...
# 1423  LINESTRING (-81.78384 24.54458, -81.73975 24.5...
# 1424  LINESTRING (-86.72690 21.26431, -86.73906 21.2...
# ...

# %%
# Plot the data
f, ax1 = plt.subplots(figsize=(12, 6))
coastlines.plot(ax=ax1)

# Add a title to your plot
ax1.set(title="Global Coastline Boundaries")
plt.show()

# %%
coastlines.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   scalerank   1428 non-null   int64
#  1   featurecla  1428 non-null   object
#  2   min_zoom    1428 non-null   float64
#  3   geometry    1428 non-null   geometry
# dtypes: float64(1), geometry(1), int64(1), object(1)
# memory usage: 44.8+ KB

# %%
coastlines
# Out:
#       scalerank featurecla  min_zoom  \
# 0             0  Coastline       1.5
# 1             0  Coastline       4.0
# 2             0  Coastline       4.0
# 3             0  Coastline       3.0
# 4             0  Coastline       4.0
# ...         ...        ...       ...
# 1423          0  Coastline       4.0
# 1424          0  Coastline       4.0
# 1425          0  Coastline       4.0
# 1426          0  Coastline       4.0
# 1427          0  Coastline       4.0
#
#                                                geometry
# 0     LINESTRING (180.00000 -16.15293, 179.84814 -16...
# 1     LINESTRING (177.25752 -17.05420, 177.28740 -17...
# 2     LINESTRING (127.37266 0.79131, 127.35381 0.847...
# 3     LINESTRING (-81.32231 24.68506, -81.42007 24.7...
# 4     LINESTRING (-80.79941 24.84629, -80.83887 24.8...
# ...                                                 ...
# 1423  LINESTRING (-81.78384 24.54458, -81.73975 24.5...
# 1424  LINESTRING (-86.72690 21.26431, -86.73906 21.2...
# ...

# %%
#How to plot

#https://www.earthdatascience.org/courses/scientists-guide-to-plotting-data-in-python/plot-with-matplotlib/introduction-to-matplotlib-plots/
